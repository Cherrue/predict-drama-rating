# %%
import time
import odbc
import pandas as pd

# %%
import re
def onlyKorean(s):
    hangeul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글과 띄어쓰기를 제외한 모든 글자
    # hangul = re.compile('[^ \u3131-\u3163\uac00-\ud7a3]+')  # 위와 동일
    hangeul_s = hangeul.sub('', s) # 한글과 띄어쓰기를 제외한 모든 부분을 제거
    not_hangeul_l = hangeul.findall(s) # 정규식에 일치되는 부분을 리스트 형태로 저장
    return hangeul_s,not_hangeul_l

# %%
connect=odbc.odbc('tv')
db=connect.cursor()

# %%
db.execute("SELECT d.drama_id,d.title FROM (select ori.drama_id,ori.video_id from tv.tvcast_video_list as ori,(SELECT drama_id,count(*) cnt FROM tv.tvcast_video_list group by drama_id having cnt>=98 and cnt<=595) as re where ori.drama_id=re.drama_id) AS v, tv.tvcast_drama_list AS d WHERE d.drama_id = v.drama_id AND d.title NOT LIKE '%웹%' group by d.drama_id;")
naver = db.fetchall()

# %%
db.execute("SELECT * FROM tv.drama;")
rate = db.fetchall()

# %%
data=[]
temp=[]
for rate_row in rate:
    rate_title = rate_row[2]
    for naver_row in naver:
        naver_title=naver_row[1]
        naver_title_re,sp_chars = onlyKorean(naver_title)
        naver_title_re = naver_title_re.strip()
        if len(naver_title_re)==0:
            continue
        if naver_title_re in rate_title:
            temp=[rate_row[0],rate_row[2],naver_row[0],naver_row[1]]
            data.append(temp)

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#      0                          1    2    3
# 0   92  주말극특별기획(KBS신화는계속된다엄마가뿔났다)  556   엄마
# 1   94                        닥터스  350  닥터스
# 2  102              주말연속극(엄마가뿔났다)  556   엄마
# 3  115                설날특집대박식당의비밀  411   대박
# 4  169           주말연속극(엄마가뿔났다<재>)  556   엄마

# %%
writer = pd.ExcelWriter('master_table2.xlsx')
df.to_excel(writer,'Sheet1')
writer.save()

# %%
data=[]
temp=[]
for rate_row in rate:
    rate_title = rate_row[2]
    rate_title_re,sp_chars = onlyKorean(rate_title)
    rate_title_re = rate_title_re.strip()
    if len(rate_title_re)==0:
        continue
    for naver_row in naver:
        naver_title=naver_row[1]
        naver_title_re,sp_chars = onlyKorean(naver_title)
        naver_title_re = naver_title_re.strip()
        if len(naver_title_re)==0:
            continue
        if naver_title_re in rate_title_re:
            temp=[rate_row[0],rate_row[2],naver_row[0],naver_row[1]]
            data.append(temp)
            
df = pd.DataFrame(data)

# %%
df
# Out:
#         0                                 1    2          3
# 0      92         주말극특별기획(KBS신화는계속된다엄마가뿔났다)  556         엄마
# 1      94                               닥터스  350        닥터스
# 2     102                     주말연속극(엄마가뿔났다)  556         엄마
# 3     115                       설날특집대박식당의비밀  411         대박
# 4     169                  주말연속극(엄마가뿔났다<재>)  556         엄마
# 5     187                    수목드라마(아빠셋엄마하나)  556         엄마
# 6     211             SBS스페셜(대한민국최초우주인꿈을쏘다)  584      72초TV
# 7     225                 특별기획휴먼다큐(사랑엄마의약속)  556         엄마
# 8     228                  특별기획휴먼다큐(사랑울보엄마)  556         엄마
# 186  4186      JTBC중앙일보한국정치학회공동주최대통령후보초청토론회  584      72초TV
# 187  4200                            귓속말<재>  126        귓속말
# 188  4210                       월화특별기획(파수꾼)   84        파수꾼
# 189  4211                초감성미니드라마(초인가족2017)  182  초인가족 2017
# 190  4211                초감성미니드라마(초인가족2017)  584      72초TV
#
# [191 rows x 4 columns]

# %%
data=[]
temp=[]
for rate_row in rate:
    rate_title = rate_row[2]
    rate_title_re,sp_chars = onlyKorean(rate_title)
    rate_title_re = rate_title_re.strip()
    if len(rate_title_re)==0:
        continue
    for naver_row in naver:
        naver_title=naver_row[1]
        naver_title_re,sp_chars = onlyKorean(naver_title)
        naver_title_re = naver_title_re.strip()
        if len(naver_title_re)==0:
            continue
        if rate_title_re in naver_title_re:
            temp=[rate_row[0],rate_row[2],naver_row[0],naver_row[1]]
            data.append(temp)
            
df = pd.DataFrame(data)

# %%
df
writer = pd.ExcelWriter('master_table2.xlsx')
df.to_excel(writer,'Sheet1')
writer.save()

# %%
data=[]
temp=[]
for rate_row in rate:
    rate_title = rate_row[2]
    rate_title_re,sp_chars = onlyKorean(rate_title)
    rate_title_re = rate_title_re.strip()
    if len(rate_title_re)==0:
        continue
    for naver_row in naver:
        naver_title=naver_row[1]
        naver_title_re,sp_chars = onlyKorean(naver_title)
        naver_title_re = naver_title_re.strip()
        if len(naver_title_re)==0:
            continue
        elif len(naver_title_re)>3:
            naver_title_re=naver_title_re[-3:]
        if naver_title_re in rate_title_re:
            temp=[rate_row[0],rate_row[2],naver_row[0],naver_row[1]]
            data.append(temp)
            
df = pd.DataFrame(data)

# %%
df
# Out:
#         0                               1    2                      3
# 0      41                  주말연속극(며느리전성시대)   51                 별별 며느리
# 1      76                           환경스페셜  263           2016 드라마 스페셜
# 2      78                         무한도전스페셜  263           2016 드라마 스페셜
# 3      81             SBS스페셜(한반도최후의낙원DMZ)  263           2016 드라마 스페셜
# 4      90             주말극특별기획(며느리전성시대스페셜)   51                 별별 며느리
# 5      90             주말극특별기획(며느리전성시대스페셜)  263           2016 드라마 스페셜
# 6      92       주말극특별기획(KBS신화는계속된다엄마가뿔났다)  556                     엄마
# 7      94                             닥터스  350                    닥터스
# 8     102                   주말연속극(엄마가뿔났다)  556                     엄마
# 9     106                         순간포착스페셜  263           2016 드라마 스페셜
# 10    107                     특별기획(이산스페셜)  263           2016 드라마 스페셜
# 11    112                  설특집스페셜강호동의1박2일  263           2016 드라마 스페셜
# 12    113              설특집스펀지2.0무서운스펀지스페셜  263           2016 드라마 스페셜
# 13    115                     설날특집대박식당의비밀  411                     대박
# 14    132                     주말극장(행복합니다)  140              당신은 너무합니다
# 15    137                         황금어장스페셜  263           2016 드라마 스페셜
# 16    150                SBS스페셜(오징어서울상경기)  263           2016 드라마 스페셜
# 17    154                     드라마스페셜(온에어)  263           2016 드라마 스페셜
# 18    169                주말연속극(엄마가뿔났다<재>)  556                     엄마
# 19    183                      월화드라마(사랑해)  146  tvN ＜그녀는 거짓말을 너무 사랑해＞
# 20    187                  수목드라마(아빠셋엄마하나)  556                     엄마
